# %% [markdown]
# Filter color with Opencv

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
path ="C:/Users/uib43225/Downloads/"
# defining the path 
image = cv2.imread(path + '1.jpg')
# load the images
plt.imshow(image)
