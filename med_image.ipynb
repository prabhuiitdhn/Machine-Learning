# %%
import numpy as np
from scipy import ndimage
from scipy import misc
import matplotlib.pyplot as plt

# %%
image = "C:/Users/Prabhu/Downloads/IMG-20190805-WA0012.jpg"

# %%
med_image = misc.imread(image)
# Out:
# C:\Users\Prabhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.

# %%
type(med_image)
# Out:
# (1016, 1015, 3)

# %%
med_image.shape
# Out:
# (1016, 1015, 3)

# %%
med_image
# Out:
# array([[[240, 240, 238],
#         [240, 240, 238],
#         [240, 240, 238],
#         ...,
#         [240, 240, 240],
#         [240, 240, 240],
#         [240, 240, 240]],
#
#        [[240, 240, 238],
#         [240, 240, 238],
#         [240, 240, 238],
#         ...,
#         [240, 240, 240],
#         [240, 240, 240],
#         [240, 240, 240]],
#
#        [[240, 240, 238],
#         [240, 240, 238],
#         [240, 240, 238],
#         ...,
#         [240, 240, 240],
#         [240, 240, 240],
#         [240, 240, 240]],
#
#        ...,
#
#        [[240, 240, 240],
#         [241, 241, 241],
#         [240, 240, 240],
#         ...,
#         [239, 239, 237],
#         [240, 240, 238],
#         [240, 240, 238]],
#
#        [[240, 240, 240],
#         [242, 242, 242],
#         [240, 240, 240],
#         ...,
#         [239, 239, 237],
#         [240, 240, 238],
#         [240, 240, 238]],
#
#        [[240, 240, 240],
#         [242, 242, 242],
#         [240, 240, 240],
# ...

# %%
plt.imshow(med_image)

# %%
plt.imshow(med_image[:, :, 0 ])

# %%
plt.imshow(med_image[:, :, 1 ])

# %%
plt.imshow(med_image[:, :, 2 ])

# %%
plt.imshow(med_image, cmap="hot")

# %%
imgplot = plt.imshow(med_image)
imgplot.set_cmap('nipy_spectral')
plt.colorbar()

# %%
plt.hist(med_image.ravel(), bins=256, range=(0.0, 255.0), fc='k', ec='k')
# Out:
# (array([5.240000e+02, 1.490000e+02, 2.020000e+02, 2.810000e+02,
#         4.800000e+02, 7.960000e+02, 1.590000e+03, 3.339000e+03,
#         6.639000e+03, 1.017800e+04, 8.554000e+03, 5.877000e+03,
#         4.502000e+03, 4.110000e+03, 3.912000e+03, 3.583000e+03,
#         3.349000e+03, 2.889000e+03, 2.563000e+03, 2.642000e+03,
#         2.512000e+03, 2.405000e+03, 2.298000e+03, 2.250000e+03,
#         2.053000e+03, 1.978000e+03, 1.930000e+03, 1.881000e+03,
#         1.682000e+03, 1.680000e+03, 1.568000e+03, 1.588000e+03,
#         1.689000e+03, 1.629000e+03, 1.714000e+03, 1.657000e+03,
#         1.467000e+03, 1.414000e+03, 1.410000e+03, 1.479000e+03,
#         1.387000e+03, 1.354000e+03, 1.369000e+03, 1.354000e+03,
#         1.249000e+03, 1.109000e+03, 1.125000e+03, 1.043000e+03,
#         9.950000e+02, 1.076000e+03, 1.087000e+03, 1.071000e+03,
#         1.123000e+03, 1.061000e+03, 9.780000e+02, 9.170000e+02,
#         9.630000e+02, 8.920000e+02, 9.040000e+02, 9.090000e+02,
# ...

# %%
med_image_gray = med_image/255.0

# %%
plt.imshow(med_image_gray)

# %%
med_image_gr = misc.imread(image, mode='L')
# Out:
# C:\Users\Prabhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.

# %%
plt.imshow(med_image_gr)
